# %% [markdown]
# <a href="https://colab.research.google.com/github/gashishkumar2201-collab/Python-class/blob/main/data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("sales (1).csv")
df["Final_Amount"]=df["Amount"]*df["Quantity"]*(1-df["Discount"]/100)
#print(df)
df1=df[df["Final_Amount"]>5000]
#print(df1)
mean_amount=df["Final_Amount"].mean()
print("The mean amount is:",mean_amount)
# Out:
# The mean amount is: 4712.884
