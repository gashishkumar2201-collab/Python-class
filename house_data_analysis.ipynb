# %% [markdown]
# <a href="https://colab.research.google.com/github/gashishkumar2201-collab/Python-class/blob/main/house_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression #using liaberery
from sklearn.model_selection import train_test_split #using this for spliting data
import numpy as np
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv("house_data_large.csv") #houseing data
#print(df)
x=df[["Sqft","Bedrooms","Bathrooms","YearBuilt","LocationCode",]]#factors provide
y=df[["Price"]]
#print(x)
#print(y)
#plt.title("House data")
#plt.xlabel("house sqft")
#plt.ylabel("price")
#plt.plot(x,y)
#plt.show()
#plt.title("House data")
#training of data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
pred=model.predict(x_test)
#print(pred)
#user data prediction
user_input=np.array([[3774,2,4,2006,1]])
user_pred=model.predict(user_input)
print("price of the house:  ",(int(user_pred)))
# Out:
# price of the house:   1299460
