# %% [markdown]
# <a href="https://colab.research.google.com/github/gashishkumar2201-collab/Python-class/blob/main/MATHMATICS_OF_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = -2
y = 6
z = -3

result = (x - y + z)**3
print(result)
# Out:
# -1331

# %% [markdown]
# ALGEBRA/TOPIC = ARITHMETIC PROGRETION
