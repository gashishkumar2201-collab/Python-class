# %% [markdown]
# <a href="https://colab.research.google.com/github/gashishkumar2201-collab/Python-class/blob/main/loan_prediction_sytem_by_using_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score
import numpy as np

import warnings
warnings.filterwarnings('ignore')


# load the data
df = pd.read_csv("loan_synthetic.csv")


# target the values
x = df[["age","income","employment_years","credit_score","loan_amount","loan_term_months","dependents","existing_debt","num_of_credit_lines","previous_defaults","months_since_last_default","debt_to_income","loan_to_income","interest_rate","approval_prob"]]
# print(x)

x = x.fillna(x.median()) # fill all the value of x
print(df.isnull().sum())

y = df[["approved"]].values.ravel() # Use .values.ravel() to get a 1D array
# print(y)

# prediction data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model=SVC() # Increased max_iter to address ConvergenceWarning
model.fit(x_train,y_train)

pred=model.predict(x_test)


#you can also take a prediction by take array and also take input individual
user_input=np.array([[22, 50000, 2.0, 600, 15000, 12, 0, 2000, 1, 0,0,0.191,0.228,0.122,0.503]])
user_pred=model.predict(user_input)
print("posbility of loan:  ",(int(user_pred)))


# input value for prdection
# age=int(input("Enter he age:"))
# income=float(input("Enter the income:"))
# employment_years=float(input("Enter the employment_years:"))
# credit_score=float(input("Enter the credit_score:"))
# loan_amount=float(input("Enter the total loan on it:"))
# loan_term_months=int((input("Enter the months that spend after taking loan:")))
# dependents=int((input("Enter how many member depend on it:")))
# existing_debt=float(input("Enter the existing_debt:"))
# num_of_credit_lines=int(input("Enter the num_of_credit_lines:"))
# previous_defaults=int((input("Enter the previous_defaults:")))
# months_since_last_default=float(input("Enter the months_since_last_default:"))
# debt_to_income=float(input("Enter the debt_to_income"))
# loan_to_income=float(input("Enter the loan to income:"))
# intrest_rate=float(input("Enter the intrest_rate:"))
# approval_prob=float(input("Enter the approval probability:"))

# check for prediction
# user_input=[[age,income,employment_years,credit_score,loan_amount,loan_term_months,dependents,existing_debt,num_of_credit_lines,previous_defaults,months_since_last_default,debt_to_income,loan_to_income,intrest_rate,approval_prob]] # Corrected 'interest_rate' to 'intrest_rate'
# prediction=model.predict(user_input)

# condition apply
# if prediction[0] == 1: # Use prediction variable and access the first element of the prediction array
#     print("Loan approved")
# else:
#     print(" Loan unapproved")


# accuracy check

accuracy= accuracy_score(y_test,pred)
print("accuracy of this model is:",accuracy)
# Out:
# age                             0
# income                         60
# employment_years               60
# credit_score                   60
# loan_amount                     0
# loan_term_months                0
# loan_purpose                    0
# marital_status                  0
# dependents                      0
# existing_debt                  60
# home_ownership                  0
# education_level                 0
# num_of_credit_lines             0
# previous_defaults               0
# months_since_last_default    2707
# debt_to_income                 60
# loan_to_income                  0
# interest_rate                   0
# approved                        0
# approval_prob                   0
# dtype: int64
# posbility of loan:   1
# accuracy of this model is: 0.8083333333333333
